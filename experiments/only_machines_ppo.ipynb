# %% [markdown]
# > ERC Starting Grant on COeXISTENCE between humans and machines in urban mobility.

# %% [markdown]
# <img src="../images/img_mileston1.png" alt="Milestone 1 Image" width="500" height="400">

# %% [markdown]
# # Title: Machine training using PPO algorithm
# ## Name: Anastasia
# ### Date: June 27, 2024
# ---

# %% [markdown]
# ### Description
#
# > In this notebook, we implement the training of three independent machine agents using the PPO algorithm.
# ---

# %% [markdown]
# ## Objective
#
# > The purpose of this notebook is to understand whether PPO algorithm can train effectively our RL agents.
# ---

# %% [markdown]
# ## Experiment Summary
#
# ### Network Architecture
# - Csomor network
#
#
# ### Agents
# | **Type**          |           |
# |-------------------|---------------------|
# | **Number**        | 3 machines |
# | **Total demand** | random |
#
#
# ### Origin and Destination Details
# | **Origin Count**      | 2                            |
# |-----------------------|------------------------------|
# | **Destination Count** | 2                            |
# | **Origin Pairing**    | 279952229#0, 115604053       |
# | **Destination Pairing**| -115602933#2, -441496282#1     |
#
#
#
# ### Hardware Utilized for Experiment Execution
# | **Type of Machine** | Personal computer (or server) |
# |----------------------|-------------------------------|
# | **CPU**              | 12th Gen Intel(R) Core(TM) i7-1255U |
# |                      | Cores: 10                   |
# |                      | Sockets: 1                  |
# |                      | Base Speed: 1.70 GHz        |
# | **Memory**           | 16GB                          |
# | **Disc (SSD)**       | 477 GB                        |
# | **Operating System** | Windows 11                    |

# %% [markdown]
# ### Imported libraries

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
from tensordict.nn import TensorDictModule, TensorDictSequential
import torch
from torchrl.collectors import SyncDataCollector
from torch.distributions import Categorical
from torchrl.envs.libs.pettingzoo import PettingZooWrapper
from torchrl.envs.transforms import TransformedEnv, RewardSum
from torchrl.envs.utils import check_env_specs
from torchrl.data.replay_buffers import ReplayBuffer
from torchrl.data.replay_buffers.samplers import SamplerWithoutReplacement
from torchrl.data.replay_buffers.storages import LazyTensorStorage
from torchrl.modules import MultiAgentMLP, ProbabilisticActor
from torchrl.objectives.value import GAE
from torchrl.objectives import ClipPPOLoss, ValueEstimators
from tqdm import tqdm
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir)

from environment import TrafficEnvironment
from keychain import Keychain as kc
from services.plotter import Plotter
from utilities import get_params

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### Hyperparameters specification

# %%
# Devices
device = (
    torch.device(0)
    if torch.cuda.is_available() and not is_fork
    else torch.device("cpu")
)
vmas_device = device  # The device where the simulator is run

# Sampling
frames_per_batch = 10  # Number of team frames collected per training iteration
n_iters = 100  # Number of sampling and training iterations
total_frames = frames_per_batch * n_iters

# Training
num_epochs = 100  # Number of optimization steps per training iteration
minibatch_size = 2  # Size of the mini-batches in each optimization step
lr = 3e-4  # Learning rate
max_grad_norm = 1.0  # Maximum norm for the gradients

# PPO
clip_epsilon = 0.2  # clip value for PPO loss
gamma = 0.99  # discount factor
lmbda = 0.9  # lambda for generalised advantage estimation
entropy_eps = 1e-5  # coefficient of the entropy term in the PPO loss

# %% [markdown]
# ### Environment Creation

# %%
params = get_params(kc.PARAMS_PATH)

# %%
env = TrafficEnvironment(params[kc.RUNNER], params[kc.ENVIRONMENT], params[kc.SIMULATOR], params[kc.AGENT_GEN], params[kc.AGENTS], params[kc.PHASE])
# Out:
# [CONFIRMED] Environment variable exists: SUMO_HOME
# [SUCCESS] Added module directory: C:\Program Files (x86)\Eclipse\Sumo\tools

# %%
env.start()

# %%
env = PettingZooWrapper(
    env=env,
    use_mask=True,
    group_map=None,
    categorical_actions=True,
    done_on_any = False
)

# %%
out_keys = []

for group, agents in env.group_map.items():
    out_keys.append((group, "episode_reward"))

print(out_keys)
# Out:
# [('19', 'episode_reward'), ('18', 'episode_reward'), ('21', 'episode_reward'), ('17', 'episode_reward')]

# %%
out_keys = [('250', 'episode_reward'), ('251', 'episode_reward'), ('252', 'episode_reward')]

# %%
env = TransformedEnv(
    env,
    RewardSum(
        in_keys=env.reward_keys,
        reset_keys=["_reset"] * len(env.group_map.keys()),
        #out_keys = out_keys
    ),
)

# %%
env.reward_keys
# Out:
# [('17', 'reward'), ('18', 'reward'), ('19', 'reward'), ('21', 'reward')]

# %%
env.full_action_spec
# Out:
# CompositeSpec(
#     19: CompositeSpec(
#         action: DiscreteTensorSpec(
#             shape=torch.Size([1]),
#             space=DiscreteBox(n=3),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete), device=cpu, shape=torch.Size([1])),
#     18: CompositeSpec(
#         action: DiscreteTensorSpec(
#             shape=torch.Size([1]),
#             space=DiscreteBox(n=3),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete), device=cpu, shape=torch.Size([1])),
#     21: CompositeSpec(
#         action: DiscreteTensorSpec(
#             shape=torch.Size([1]),
#             space=DiscreteBox(n=3),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete), device=cpu, shape=torch.Size([1])),
#     17: CompositeSpec(
#         action: DiscreteTensorSpec(
#             shape=torch.Size([1]),
#             space=DiscreteBox(n=3),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete), device=cpu, shape=torch.Size([1])), device=cpu, shape=torch.Size([]))

# %%
env.group_map.keys()
# Out:
# dict_keys(['19', '18', '21', '17'])

# %%
check_env_specs(env)
# Out:
# 2024-07-15 17:10:11,482 [torchrl][INFO] check_env_specs succeeded!

# %%
reset_td = env.reset()

# %% [markdown]
# ### Policy network

# %%
policy_modules = {}
for group, agents in env.group_map.items():
    share_parameters_policy = False  # Can change this based on the group

    policy_net = MultiAgentMLP(
        n_agent_inputs=env.observation_spec[group, "observation"].shape[
            -1
        ],  # n_obs_per_agent
        n_agent_outputs= env.full_action_spec[group, "action"].space.n,  # n_actions_per_agents
        n_agents=len(agents),  # Number of agents in the group
        centralised=False,  # the policies are decentralised (i.e., each agent will act from its local observation)
        share_params=share_parameters_policy,
        device=device,
        depth=3,
        num_cells=64,
        activation_class=torch.nn.Tanh,
    )

    # Wrap the neural network in a :class:`~tensordict.nn.TensorDictModule`.
    # This is simply a module that will read the ``in_keys`` from a tensordict, feed them to the
    # neural networks, and write the
    # outputs in-place at the ``out_keys``.

    policy_module = TensorDictModule(
        policy_net,
        in_keys=[(group, "observation")],
        out_keys=[(group, "logits")],
    )  # We just name the input and output that the network will read and write to the input tensordict
    policy_modules[group] = policy_module

# %%
policy_modules
# Out:
# {'19': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=3, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('19', 'observation')],
#      out_keys=[('19', 'logits')]),
#  '18': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=3, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('18', 'observation')],
#      out_keys=[('18', 'logits')]),
#  '21': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=3, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('21', 'observation')],
#      out_keys=[('21', 'logits')]),
#  '17': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=3, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('17', 'observation')],
#      out_keys=[('17', 'logits')])}

# %%
for group, agents in env.group_map.items():
    print(group, agents)
# Out:
# 19 ['19']
# 18 ['18']
# 21 ['21']
# 17 ['17']

# %%
policies = {}
for group, _agents in env.group_map.items():
    policy = ProbabilisticActor(
        module=policy_modules[group],
        spec=env.full_action_spec[group, "action"],
        in_keys=[(group, "logits")],
        out_keys=[(group, "action")],
        distribution_class=Categorical,
        return_log_prob=True,
        log_prob_key=(group, "sample_log_prob"),
    )
    policies[group] = policy

# %% [markdown]
# ### Critic network

# %%
critic_modules = {}
for group, agents in env.group_map.items():
    share_parameters_critic = False
    mappo = False  # IPPO if False

    critic_net = MultiAgentMLP(
        n_agent_inputs=env.observation_spec[group, "observation"].shape[-1],
        n_agent_outputs=1, 
        n_agents=len(agents),
        centralised=mappo,
        share_params=share_parameters_critic,
        device=device,
        depth=4,
        num_cells=64,
        activation_class=torch.nn.Tanh,
    )

    critic_module = TensorDictModule(
        module=critic_net,
        in_keys=[(group, "observation")],
        out_keys=[(group, "state_value")],
    )
    critic_modules[group] = critic_module

# %%
critic_modules
# Out:
# {'19': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=64, bias=True)
#            (7): Tanh()
#            (8): Linear(in_features=64, out_features=1, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('19', 'observation')],
#      out_keys=[('19', 'state_value')]),
#  '18': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=64, bias=True)
#            (7): Tanh()
#            (8): Linear(in_features=64, out_features=1, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('18', 'observation')],
#      out_keys=[('18', 'state_value')]),
#  '21': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=64, bias=True)
#            (7): Tanh()
#            (8): Linear(in_features=64, out_features=1, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('21', 'observation')],
#      out_keys=[('21', 'state_value')]),
#  '17': TensorDictModule(
#      module=MultiAgentMLP(
#        (agent_networks): ModuleList(
#          (0): MLP(
#            (0): Linear(in_features=3, out_features=64, bias=True)
#            (1): Tanh()
#            (2): Linear(in_features=64, out_features=64, bias=True)
#            (3): Tanh()
#            (4): Linear(in_features=64, out_features=64, bias=True)
#            (5): Tanh()
#            (6): Linear(in_features=64, out_features=64, bias=True)
#            (7): Tanh()
#            (8): Linear(in_features=64, out_features=1, bias=True)
#          )
#        )
#      ),
#      device=cpu,
#      in_keys=[('17', 'observation')],
#      out_keys=[('17', 'state_value')])}

# %%
reset_td = env.reset()
for group, _agents in env.group_map.items():
    print(
        f"Running value and policy for group '{group}':",
        critic_modules[group](policies[group](reset_td)),
    )
# Out:
# Running value and policy for group '19': TensorDict(
#     fields={
#         17: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         18: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         19: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         21: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         done: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         terminated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([]),
#     device=cpu,
#     is_shared=False)
# Running value and policy for group '18': TensorDict(
#     fields={
#         17: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         18: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         19: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         21: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         done: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         terminated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([]),
#     device=cpu,
#     is_shared=False)
# Running value and policy for group '21': TensorDict(
#     fields={
#         17: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         18: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         19: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         21: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         done: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         terminated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([]),
#     device=cpu,
#     is_shared=False)
# Running value and policy for group '17': TensorDict(
#     fields={
#         17: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         18: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         19: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         21: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.int64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 logits: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 mask: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 observation: Tensor(shape=torch.Size([1, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 sample_log_prob: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 state_value: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([1]),
#             device=cpu,
#             is_shared=False),
#         done: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         terminated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#         truncated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False)},
#     batch_size=torch.Size([]),
#     device=cpu,
#     is_shared=False)

# %%
policy = TensorDictSequential(*policies.values())

# %% [markdown]
# ### Collector

# %%
collector = SyncDataCollector(
    env,
    policy,
    device=device,
    storing_device=device,
    frames_per_batch=frames_per_batch,
    reset_at_each_iter=False,
    total_frames=total_frames,
)

# %% [markdown]
# ### Replay Buffer

# %%
replay_buffers = {}
for group, _agents in env.group_map.items():
    replay_buffers[group] = ReplayBuffer(
        storage=LazyTensorStorage(
            frames_per_batch, device=device
        ),  # We store the frames_per_batch collected at each iteration
        sampler=SamplerWithoutReplacement(),
        batch_size=minibatch_size,  # We will sample minibatches of this size
    )

# %% [markdown]
# ### PPO loss function

# %%
loss_modules = {}
losses = {}
optimizers = {}

for group, _agents in env.group_map.items():
    loss_module = ClipPPOLoss(
        actor_network=policies[group],
        critic_network=critic_modules[group],
        clip_epsilon=clip_epsilon,
        entropy_coef=entropy_eps,
        normalize_advantage=False,  # Important to avoid normalizing across the agent dimension
    )
    loss_module.set_keys(  # We have to tell the loss where to find the keys
        reward=(group, "reward"),  
        action=(group, "action"), 
        sample_log_prob=(group, "sample_log_prob"),
        value=(group, "state_value"),
        done=(group, "done"),
        terminated=(group, "terminated"),
        advantage=(group, "advantage")
    )

    loss_module.make_value_estimator(
        ValueEstimators.GAE, gamma=gamma, lmbda=lmbda
    )  # We build GAE

    GAE = loss_module.value_estimator

    losses[group] = loss_module

    optimizer = torch.optim.Adam(loss_module.parameters(), lr)
    loss_modules[group] = (loss_module, optimizer)

    optimizers[group] = optimizer


# Access loss module for the first group for example
group = next(iter(env.group_map))
loss_module, optimizer = loss_modules[group]

# %% [markdown]
# ### Training loop

# %%
pbar = tqdm(
    total=n_iters,
    desc=", ".join(
        [f"episode_reward_mean_{group} = 0" for group in env.group_map.keys()]
    ),
)
episode_reward_mean_map = {group: [] for group in env.group_map.keys()}

loss = {group: [] for group in env.group_map.keys()}
loss_objective = {group: [] for group in env.group_map.keys()}
loss_critic = {group: [] for group in env.group_map.keys()}
loss_entropy = {group: [] for group in env.group_map.keys()}

for tensordict_data in collector:

    # Update done and terminated for both agents
    for group, _agents in env.group_map.items():
        tensordict_data.set(
            ("next", group, "done"),
            tensordict_data.get(("next", "done"))
            .unsqueeze(-1)
            .expand(tensordict_data.get_item_shape(("next", group, "reward"))),  # Adjust index to start from 0
        )
        tensordict_data.set(
            ("next", group, "terminated"),
            tensordict_data.get(("next", "terminated"))
            .unsqueeze(-1)
            .expand(tensordict_data.get_item_shape(("next", group, "reward"))),  # Adjust index to start from 0
        )

    # Compute GAE for both agents
    with torch.no_grad():
        for group, _agents in env.group_map.items():
            module = GAE(
                tensordict_data,
                params=loss_modules[group][0].critic_network_params,
                target_params=loss_modules[group][0].target_critic_network_params,
            )

    # Flatten and extend data for both agents
    for group, _agents in env.group_map.items():
        data_view = tensordict_data.reshape(-1)  # Flatten the batch size to shuffle data
        replay_buffers[group].extend(data_view)

    for epoch in range(num_epochs):
        for group, _agents in env.group_map.items():
            for _ in range(frames_per_batch // minibatch_size):
                subdata = replay_buffers[group].sample()
                #print("Inside inner loop", subdata, replay_buffers, "\n\n")
                loss_vals = losses[group](subdata)

                loss_value = (
                    loss_vals["loss_objective"]
                    + loss_vals["loss_critic"]
                    + loss_vals["loss_entropy"]
                )

                loss_value.backward()

                if torch.isnan(loss_value).any():
                    raise ValueError("NaNs in the loss")

                loss[group].append(loss_value)
                loss_objective[group].append(loss_vals["loss_objective"])
                loss_critic[group].append(loss_vals["loss_critic"])
                loss_entropy[group].append(loss_vals["loss_entropy"])

                torch.nn.utils.clip_grad_norm_(
                    losses[group].parameters(), max_grad_norm
                )  # Optional

                optimizers[group].step()
                optimizers[group].zero_grad()

    # Update policy weights for both agents
    #for group, _agents in env.group_map.items():
    collector.update_policy_weights_()
   

    for group, _agents in env.group_map.items():
        done = tensordict_data.get(("next", group, "done"))  # Get done status for the group

        episode_reward_mean = (
            tensordict_data.get(("next", group, "reward"))[
                tensordict_data.get(("next", group, "done"))
            ]
            .mean()
            .item()
        )

        episode_reward_mean_map[group].append(episode_reward_mean)

    pbar.set_description(
        ", ".join(
            [
                f"episode_reward_mean_{group} = {episode_reward_mean_map[group][-1]}"
                for group in env.group_map.keys()
            ]
        ),
        refresh=False,
    )
    pbar.update()
# Out:
# episode_reward_mean_19 = 0, episode_reward_mean_18 = 0, episode_reward_mean_21 = 0, episode_reward_mean_17 = 0:   0%|          | 0/100 [00:00<?, ?it/s]
# episode_reward_mean_19 = 0, episode_reward_mean_18 = 0, episode_reward_mean_21 = 0, episode_reward_mean_17 = 0:   0%|          | 0/100 [00:22<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 50
#      48 subdata = replay_buffers[group].sample()
#      49 #print("Inside inner loop", subdata, replay_buffers, "\n\n")
# ---> 50 loss_vals = losses[group](subdata)
#      52 loss_value = (
#      53     loss_vals["loss_objective"]
#      54     + loss_vals["loss_critic"]
#      55     + loss_vals["loss_entropy"]
#      56 )
#      58 loss_value.backward()
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torch\nn\modules\module.py:1561, in Module._call_impl(self, *args, **kwargs)
#    1558     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1559     args = bw_hook.setup_input_hook(args)
# -> 1561 result = forward_call(*args, **kwargs)
#    1562 if _global_forward_hooks or self._forward_hooks:
#    1563     for hook_id, hook in (
#    1564         *_global_forward_hooks.items(),
#    1565         *self._forward_hooks.items(),
#    1566     ):
#    1567         # mark that always called hook is run
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\tensordict\_contextlib.py:126, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     123 @functools.wraps(func)
#     124 def decorate_context(*args, **kwargs):
#     125     with ctx_factory():
# --> 126         return func(*args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\tensordict\nn\common.py:289, in dispatch.__call__.<locals>.wrapper(_self, *args, **kwargs)
#     287     out = tuple(out[key] for key in dest)
#     288     return out[0] if len(out) == 1 else out
# --> 289 return func(_self, tensordict, *args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\ppo.py:751, in ClipPPOLoss.forward(self, tensordict)
#     749 advantage = tensordict.get(self.tensor_keys.advantage, None)
#     750 if advantage is None:
# --> 751     self.value_estimator(
#     752         tensordict,
#     753         params=self._cached_critic_network_params_detached,
#     754         target_params=self.target_critic_network_params,
#     755     )
#     756     advantage = tensordict.get(self.tensor_keys.advantage)
#     757 if self.normalize_advantage and advantage.numel() > 1:
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\value\advantages.py:68, in _self_set_skip_existing.<locals>.new_func(self, *args, **kwargs)
#      66     with set_skip_existing(self.skip_existing):
#      67         return fun(self, *args, **kwargs)
# ---> 68 return fun(self, *args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\value\advantages.py:57, in _self_set_grad_enabled.<locals>.new_fun(self, *args, **kwargs)
#      54 @wraps(fun)
#      55 def new_fun(self, *args, **kwargs):
#      56     with torch.set_grad_enabled(self.differentiable):
# ---> 57         return fun(self, *args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\tensordict\nn\common.py:289, in dispatch.__call__.<locals>.wrapper(_self, *args, **kwargs)
#     287     out = tuple(out[key] for key in dest)
#     288     return out[0] if len(out) == 1 else out
# --> 289 return func(_self, tensordict, *args, **kwargs)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\value\advantages.py:1288, in GAE.forward(self, tensordict, params, target_params)
#    1286 terminated = tensordict.get(("next", self.tensor_keys.terminated), default=done)
#    1287 if self.vectorized:
# -> 1288     adv, value_target = vec_generalized_advantage_estimate(
#    1289         gamma,
#    1290         lmbda,
#    1291         value,
#    1292         next_value,
#    1293         reward,
#    1294         done=done,
#    1295         terminated=terminated,
#    1296         time_dim=tensordict.ndim - 1,
#    1297     )
#    1298 else:
#    1299     adv, value_target = generalized_advantage_estimate(
#    1300         gamma,
#    1301         lmbda,
#    (...)
#    1307         time_dim=tensordict.ndim - 1,
#    1308     )
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\value\functional.py:90, in _transpose_time.<locals>.transposed_fun(*args, **kwargs)
#      88     single_dim = single_dim or sd
#      89     kwargs[k] = item
# ---> 90 out = fun(*args, time_dim=-2, **kwargs)
#      91 if isinstance(out, torch.Tensor):
#      92     out = transpose_tensor(out)[0]
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\value\functional.py:313, in vec_generalized_advantage_estimate(gamma, lmbda, state_value, next_state_value, reward, done, terminated, time_dim)
#     310     gammalmbdas = not_done * value
#     311 else:
#     312     # when gamma and lmbda are scalars, use fast_vec_gae implementation
# --> 313     return _fast_vec_gae(
#     314         reward=reward,
#     315         state_value=state_value,
#     316         next_state_value=next_state_value,
#     317         done=done,
#     318         terminated=terminated,
#     319         gamma=gamma,
#     320         lmbda=lmbda,
#     321     )
#     323 gammalmbdas = _make_gammas_tensor(gammalmbdas, time_steps, True)
#     324 gammalmbdas = gammalmbdas.cumprod(-2)
#
# File c:\Users\Anastasia\anaconda3\envs\torchrl\Lib\site-packages\torchrl\objectives\value\functional.py:255, in _fast_vec_gae(reward, state_value, next_state_value, done, terminated, gamma, lmbda, thr)
#     251 advantage = advantage[mask].view_as(reward)
#     253 value_target = advantage + state_value
# --> 255 advantage = advantage.transpose(-1, -2)
#     256 value_target = value_target.transpose(-1, -2)
#     258 return advantage, value_target
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mean reward

# %%
plt.figure()
for group in env.group_map.keys():
    rewards = episode_reward_mean_map[group]
    plt.plot(rewards, label=group)

plt.title('Mean Rewards for All Groups')
plt.xlabel('Episode')
plt.ylabel('Mean Reward')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Losses

# %% [markdown]
# ### Total loss

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for agent_id, losses in loss.items():
    losses_np = [loss.detach().numpy() for loss in losses]
    plt.plot(losses_np, label=f'Agent {agent_id}')

plt.title('Total Loss per Agent')
plt.xlabel('Training Step')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Objective loss

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for agent_id, losses in loss_objective.items():
    losses_np = [loss.detach().numpy() for loss in losses]
    plt.plot(losses_np, label=f'Agent {agent_id}')

plt.title('Objective Loss per Agent')
plt.xlabel('Training Step')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Entropy loss

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for agent_id, losses in loss_entropy.items():
    losses_np = [loss.detach().numpy() for loss in losses]
    plt.plot(losses_np, label=f'Agent {agent_id}')

plt.title('Entropy Loss per Agent')
plt.xlabel('Training Step')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Critic loss

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for agent_id, losses in loss_critic.items():
    losses_np = [loss.detach().numpy() for loss in losses]
    plt.plot(losses_np, label=f'Agent {agent_id}')

plt.title('Critic Loss per Agent')
plt.xlabel('Training Step')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
from services import plotter

plotter(params[kc.PLOTTER])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 3
#       1 from services import plotter
# ----> 3 plotter(params[kc.PLOTTER])
#
# File c:\Users\Anastasia\OneDrive - Uniwersytet Jagielloński\Documents\torch-rl-trials\Milestone-One\services\plotter.py:487, in plotter(params)
#     485 def plotter(params):
#     486     plotter = Plotter(params)
# --> 487     plotter.plot()
#     488     return plotter
#
# File c:\Users\Anastasia\OneDrive - Uniwersytet Jagielloński\Documents\torch-rl-trials\Milestone-One\services\plotter.py:53, in Plotter.plot(self)
#      51 self.visualize_mean_rewards()
#      52 self.visualize_mean_travel_times()
# ---> 53 self.visualize_tt_distributions()
#      54 self.visualize_actions()
#      55 self.visualize_action_shifts()
#
# File c:\Users\Anastasia\OneDrive - Uniwersytet Jagielloński\Documents\torch-rl-trials\Milestone-One\services\plotter.py:183, in Plotter.visualize_tt_distributions(self)
#     181 all_travel_times = self._retrieve_data_per_kind(kc.TRAVEL_TIME)
#     182 eps_to_plot = [ep-1 for ep in self.phases[1:]] + [self.saved_episodes[-1]]
# --> 183 data_to_plot = [all_travel_times[kc.TYPE_HUMAN][ep] for ep in eps_to_plot]
#     184 labels = [f'Humans ({ph})' for ph in self.phase_names]
#     186 bplot = axes[2].boxplot(data_to_plot, labels=labels, patch_artist=True)
#
# File c:\Users\Anastasia\OneDrive - Uniwersytet Jagielloński\Documents\torch-rl-trials\Milestone-One\services\plotter.py:183, in <listcomp>(.0)
#     181 all_travel_times = self._retrieve_data_per_kind(kc.TRAVEL_TIME)
#     182 eps_to_plot = [ep-1 for ep in self.phases[1:]] + [self.saved_episodes[-1]]
# --> 183 data_to_plot = [all_travel_times[kc.TYPE_HUMAN][ep] for ep in eps_to_plot]
#     184 labels = [f'Humans ({ph})' for ph in self.phase_names]
#     186 bplot = axes[2].boxplot(data_to_plot, labels=labels, patch_artist=True)
#
# KeyError: 'Human'
