# %% [markdown]
# ![](Coexistence-logo.png)

# %% [markdown]
# > ERC Starting Grant on COeXISTENCE between humans and machines in urban mobility.

# %% [markdown]
# # Milestone 1

# %% [markdown]
# <img src="img_mileston1.png" alt="Milestone 1 Image" width="500" height="400">

# %% [markdown]
# # Title: Tutorial on Stable Baselines3 function's parameters
# ## Name: Anastasia
# ### Date: March 6, 2024
# ---

# %% [markdown]
# ### Description
#
# > In this notebook the parameters and the metrics used to implement the Stable-Baselines3 algorithms will be checked.
#
#
# ---

# %% [markdown]
# ### Duration of Experiment Execution
#
# > The duration of this experiment was measured to be...
# ---

# %% [markdown]
# ## Experiment Objective
#
# > The objective of this notebook is to get a deeper understanding of the quality of the training implemented in our experiments by understanding the metrics used by the Stable-Baslines3 algorithms.
# ---

# %% [markdown]
# ### PPO algorithm

# %% [markdown]
# #### Training
#
# | Parameter             | Value         |
# |-----------------------|---------------|
# | approx_kl             | 1.7881394e-08 |
# | clip_fraction         | 0             |
# | clip_range            | 0.2           |
# | entropy_loss          | -0.00679      |
# | explained_variance    | -1.68e+09     |
# | learning_rate         | 0.001         |
# | loss                  | -9.06e-05     |
# | n_updates             | 990           |
# | policy_gradient_loss  | -4.73e-05     |
# | value_loss            | 2.39e-05      |

# %% [markdown]
# #### Approximate form of KL divergence for early stopping
