# %% [markdown]
# ![](Coexistence-logo.png)

# %% [markdown]
# > ERC Starting Grant on COeXISTENCE between humans and machines in urban mobility.

# %% [markdown]
# # Milestone 1

# %% [markdown]
# <img src="img_mileston1.png" alt="Milestone 1 Image" width="500" height="400">

# %% [markdown]
# # Title: Tutorial on Stable Baselines3 function's parameters
# ## Name: Anastasia
# ### Date: March 6, 2024
# ---

# %% [markdown]
# ### Description
#
# > In this notebook the parameters and the metrics used to implement the Stable-Baselines3 algorithms will be checked. More details [here](https://stable-baselines3.readthedocs.io/en/master/common/logger.html).
#
#
# ---

# %% [markdown]
# ### Duration of Experiment Execution
#
# > The duration of this experiment was measured to be...
# ---

# %% [markdown]
# ## Experiment Objective
#
# > The objective of this notebook is to get a deeper understanding of the quality of the training implemented in our experiments by understanding the metrics used by the Stable-Baslines3 algorithms.
# ---

# %% [markdown]
# ## PPO algorithm

# %% [markdown]
# ### Loger Outputs

# %% [markdown]
# |                       |              |
# |-----------------------|--------------|
# | **eval/**                |              |
# |    mean_ep_length     | 200          |
# |    mean_reward        | -157         |
# | **rollout/**            |              |
# |    ep_len_mean        | 200          |
# |    ep_rew_mean        | -227         |
# | **time/**              |              |
# |    fps                | 972          |
# |    iterations         | 19           |
# |    time_elapsed       | 80           |
# |    total_timesteps    | 77824        |
# | **train/**            |              |
# |    approx_kl          | 0.037781604  |
# |    clip_fraction      | 0.243        |
# |    clip_range         | 0.2          |
# |    entropy_loss       | -1.06        |
# |    explained_variance | 0.999        |
# |    learning_rate      | 0.001        |
# |    loss               | 0.245        |
# |    n_updates          | 180          |
# |    policy_gradient_loss | -0.00398  |
# |    std                | 0.205        |
# |    value_loss         | 0.226        |

# %% [markdown]
# #### Evaluation

# %% [markdown]
# - `mean_ep_length`: Mean Episode Length
# - `mean_reward`: Mean Episodic Reward

# %% [markdown]
# #### Rollout
#
# The term "rollout" is in regard to an execution of a policy from the current state when there is some uncertainty about the next state or outcome, it is one simulation from the current state.
#
# - `ep_len_mean`: Mean Episode Length
# - `ep_rew_mean`: Mean Episodic Reward

# %% [markdown]
# #### Time

# %% [markdown]
# - `episodes`: Total number of episodes
# - `fps`: Number of frames per seconds
# - `iterations`: Number of iterations (data collection + policy update for A2C/PPO)
# - `time_elapsed`: Time is seconds since the beginning of training
# - `total_timesteps`: Total number of timesteps
#
#
# Total timesteps is the number of steps in total the agent will do for any environment. The total timesteps can be across several episodes, meaning that this value is not bound to maximum.

# %% [markdown]
# $$ \text{number of updates} = \frac{\text{total timesteps}}{\text{batch size}} $$

# %% [markdown]
# #### Train

# %% [markdown]
# #### Approximate form of KL divergence for early stopping

# %% [markdown]
# #### Clip fraction
#
# It is the mean

# %% [markdown]
# #### Clip range
