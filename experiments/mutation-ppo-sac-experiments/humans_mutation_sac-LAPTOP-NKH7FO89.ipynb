# %% [markdown]
# > ERC Starting Grant on COeXISTENCE between humans and machines in urban mobility.

# %% [markdown]
# <img src="../../images/img_mileston1.png" alt="Milestone 1 Image" width="500" height="400">

# %% [markdown]
# # Title: Machine training using SAC algorithm
# ## Name: Anastasia
# ### Date: June 27, 2024
# ---

# %% [markdown]
# ### Description
#
# > In this notebook, we implement the training of independent machine agents using the SAC algorithm.
# ---

# %% [markdown]
# ## Objective
#
# > The purpose of this notebook is to understand whether SAC algorithm can train effectively our RL agents.
# ---

# %% [markdown]
# ## Experiment Summary
#
# ### Network Architecture
# - Csomor network
# ---
#
# ### Episodes
# - 100 human learning - 200 machine learning
# ---
#
# ### Agents
# | **Type**          |           |
# |-------------------|---------------------|
# | **Number**        | 8 humans(before mutation) -> 4 humans, 4 machines (after mutation) |
# | **Total demand** | random |
# ---
#
#
#
# ### Origin and Destination Details
# | **Origin Count**      | 2                            |
# |-----------------------|------------------------------|
# | **Destination Count** | 2                            |
# | **Origin Pairing**    | 279952229#0, 115604053       |
# | **Destination Pairing**| -115602933#2, -441496282#1     |
# ---
#
# ### Execution time
# - 5 h
# ---
#
#
#
#
# ### Hardware Utilized for Experiment Execution
# | **Type of Machine** | Personal computer (or server) |
# |----------------------|-------------------------------|
# | **CPU**              | 12th Gen Intel(R) Core(TM) i7-1255U |
# |                      | Cores: 10                   |
# |                      | Sockets: 1                  |
# |                      | Base Speed: 1.70 GHz        |
# | **Memory**           | 16GB                          |
# | **Disc (SSD)**       | 477 GB                        |
# | **Operating System** | Windows 11                    |
# ---

# %% [markdown]
# ### Imported libraries

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
from tensordict.nn import TensorDictModule, TensorDictSequential
import torch
from torchrl.collectors import SyncDataCollector
from torch.distributions import Categorical, OneHotCategorical
from torchrl.envs.libs.pettingzoo import PettingZooWrapper
from torchrl.envs.transforms import TransformedEnv, RewardSum
from torchrl.envs.utils import check_env_specs
from torchrl.data.replay_buffers import ReplayBuffer
from torchrl.data import TensorDictReplayBuffer
from torchrl.data.replay_buffers.samplers import SamplerWithoutReplacement
from torchrl.data.replay_buffers.storages import LazyTensorStorage
from torchrl.modules import MultiAgentMLP, ProbabilisticActor, ValueOperator
from torchrl.objectives.value import GAE
from torchrl.objectives import ClipPPOLoss, ValueEstimators
from torchrl.objectives import DiscreteSACLoss, SACLoss, SoftUpdate, ValueEstimators
from torchrl._utils import logger as torchrl_logger
from tensordict import TensorDictBase
from tqdm import tqdm
from torchrl.record.loggers import generate_exp_name, get_logger, Logger
from torchrl.record.loggers.wandb import WandbLogger
from torchrl.data.replay_buffers import LazyMemmapStorage
import time
import sys

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir)

from environment import TrafficEnvironment
from keychain import Keychain as kc
from services.plotter import Plotter
from utilities import get_params

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### Hyperparameters specification

# %%
# Devices
device = (
    torch.device(0)
    if torch.cuda.is_available() and not is_fork
    else torch.device("cpu")
)
vmas_device = device  # The device where the simulator is run

# Sampling
frames_per_batch = 16  # Number of team frames collected per training iteration
n_iters = 100  # Number of sampling and training iterations
total_frames = frames_per_batch * n_iters

# Training
num_epochs = 100  # Number of optimization steps per training iteration
minibatch_size = 2  # Size of the mini-batches in each optimization step
lr = 3e-4  # Learning rate
max_grad_norm = 1.0  # Maximum norm for the gradients

# SAC
gamma = 0.99  # discount factor
tau = 0.02

# %% [markdown]
# ### Environment Creation

# %%
params = get_params(kc.PARAMS_PATH)

# %%
env = TrafficEnvironment(params[kc.RUNNER], params[kc.ENVIRONMENT], params[kc.SIMULATOR], params[kc.AGENT_GEN], params[kc.AGENTS], params[kc.PHASE])
# Out:
# [CONFIRMED] Environment variable exists: SUMO_HOME
# [SUCCESS] Added module directory: C:\Program Files (x86)\Eclipse\Sumo\tools

# %%
env.start()
env.reset()
# Out:
# ({}, {})

# %% [markdown]
# ### Human learning

# %%
num_episodes = 100

for episode in range(num_episodes):
    env.step()

# %% [markdown]
# ### Mutation

# %%
env.mutation()
# Out:
# Mutation is about to happen!
#
# Now there are %s human agents.
#  4

# %% [markdown]
# ### Machine learning

# %%
env = PettingZooWrapper(
    env=env,
    use_mask=True,
    group_map=None,
    categorical_actions=True,
    done_on_any = False
)

# %%
env = TransformedEnv(
    env,
    RewardSum(
        in_keys=env.reward_keys,
        reset_keys=["_reset"] * len(env.group_map.keys()),
    ),
)

# %%
check_env_specs(env)
# Out:
# 2024-07-20 14:26:25,918 [torchrl][INFO] check_env_specs succeeded!

# %%
reset_td = env.reset()

# %% [markdown]
# ### Policy network

# %%
policy_modules = {}
for group, agents in env.group_map.items():
    share_parameters_policy = False  # Can change this based on the group

    policy_net = MultiAgentMLP(
        n_agent_inputs=env.observation_spec[group, "observation"].shape[-1], 
        n_agent_outputs = env.full_action_spec[group, "action"].space.n,  # n_actions_per_agents
        n_agents=len(agents),  # Number of agents in the group
        centralised=False,  # the policies are decentralised (i.e., each agent will act from its local observation)
        share_params=share_parameters_policy,
        device=device,
        depth=4,
        num_cells=64,
        activation_class=torch.nn.Tanh,
    )

    policy_module = TensorDictModule(
        policy_net,
        in_keys=[(group, "observation")],
        out_keys=[(group, "logits")],
    )  # We just name the input and output that the network will read and write to the input tensordict
    policy_modules[group] = policy_module

# %%
policies = {}

for group, _agents in env.group_map.items():

    policy = ProbabilisticActor(
        module=policy_modules[group],
        spec=env.full_action_spec[group, "action"],
        in_keys=[(group, "logits")],
        out_keys=[(group, "action")],
        distribution_class=Categorical,
        return_log_prob=True,
        log_prob_key=(group, "sample_log_prob"),
    )
    
    policies[group] = policy

# %% [markdown]
# ### Critic network

# %%
critic_modules = {}
for group, agents in env.group_map.items():
    share_parameters_critic = False
    mappo = False  # IPPO if False

    critic_net = MultiAgentMLP(
        n_agent_inputs=env.observation_spec[group, "observation"].shape[-1],
        n_agent_outputs = env.full_action_spec[group, "action"].space.n, 
        n_agents = len(agents),
        centralised=mappo,
        share_params=share_parameters_critic,
        device=device,
        depth=4,
        num_cells=128,
        activation_class=torch.nn.Tanh,
    )

    value_module = ValueOperator(
        module=critic_net,
        in_keys=[(group, "observation")],
        out_keys=[(group, "action_value")],
    )
    critic_modules[group] = value_module

# %%
reset_td = env.reset()
for group, _agents in env.group_map.items():
    critic_modules[group](policies[group](reset_td))

# %%
policy = TensorDictSequential(*policies.values())

# %% [markdown]
# ### Collector

# %%
collector = SyncDataCollector(
    env,
    policy,
    device=device,
    storing_device=device,
    frames_per_batch=frames_per_batch,
    reset_at_each_iter=True,
    total_frames=total_frames,
)

# %% [markdown]
# ### Replay Buffer

# %%
replay_buffers = {}
for group, _agents in env.group_map.items():
    replay_buffers[group] = TensorDictReplayBuffer(
        storage=LazyMemmapStorage(
            10*frames_per_batch, device=device
        ),  # We store the frames_per_batch collected at each iteration
        sampler=SamplerWithoutReplacement(),
        batch_size=10*minibatch_size,  # We will sample minibatches of this size
    )

# %% [markdown]
# ### SAC loss function

# %%
losses = {}
optimizers = {}
target_net_updaters = {}

for group, _agents in env.group_map.items():
    
    loss_module = DiscreteSACLoss(
        actor_network=policies[group],
        qvalue_network=critic_modules[group],
        delay_qvalue=True, ## Whether to separate the target Q value networks from the Q value networks used for data collection.
        num_actions=env.action_spec[group]['action'].space.n,
        action_space=env.action_spec[group]['action'] ### changed this - don't know if it's correct
    )
    loss_module.set_keys(  # We have to tell the loss where to find the keys
        reward=(group, "reward"),  
        action_value=(group, "action_value"),
        action=(group, "action"), 
        done=(group, "done"),
        terminated=(group, "terminated"),
    )

    loss_module.make_value_estimator(ValueEstimators.TD0, gamma=gamma)

    target_net_updaters[group] = SoftUpdate(loss_module, eps=1 - tau)


    losses[group] = loss_module

    optimizers[group] = torch.optim.Adam(loss_module.parameters(), lr)

# %% [markdown]
# ### Training loop

# %%
pbar = tqdm(
    total=n_iters,
    desc=", ".join(
        [f"episode_reward_mean_{group} = 0" for group in env.group_map.keys()]
    ),
)
sampling_start = time.time()
total_time = 0
episode_reward_mean_map = {group: [] for group in env.group_map.keys()}


for i, tensordict_data in enumerate(collector):
    torchrl_logger.info(f"\nIteration {i}")

    sampling_time = time.time() - sampling_start

    current_frames = tensordict_data.numel()
    total_frames += current_frames

    for group, _agents in env.group_map.items():
        data_view = tensordict_data.reshape(-1)  # Flatten the batch size to shuffle data
        replay_buffers[group].extend(data_view)

    training_tds = []
    training_start = time.time()
    for _ in range(num_epochs):
        for group, _agents in env.group_map.items():
            for _ in range(frames_per_batch // minibatch_size):

                subdata = replay_buffers[group].sample()

                loss_vals = losses[group](subdata)
                training_tds.append(loss_vals.detach())

                loss_value = (
                    loss_vals["loss_actor"]
                    + loss_vals["loss_alpha"]
                    + loss_vals["loss_qvalue"]
                )

                loss_value.backward()

                total_norm = torch.nn.utils.clip_grad_norm_(
                    loss_module.parameters(), max_grad_norm
                )
                training_tds[-1].set("grad_norm", total_norm.mean())

                optimizers[group].step()
                optimizers[group].zero_grad()
                
                target_net_updaters[group].step()

    collector.update_policy_weights_()

    training_time = time.time() - training_start

    iteration_time = sampling_time + training_time
    total_time += iteration_time
    training_tds = torch.stack(training_tds)

    for group, _agents in env.group_map.items():
        done = tensordict_data.get(("next", group, "done"))  # Get done status for the group

        episode_reward_mean = (
            tensordict_data.get(("next", group, "reward"))[
                tensordict_data.get(("next", group, "done"))
            ]
            .mean()
            .item()
        )

        episode_reward_mean_map[group].append(episode_reward_mean)

    pbar.set_description(
        ", ".join(
            [
                f"episode_reward_mean_{group} = {episode_reward_mean_map[group][-1]}"
                for group in env.group_map.keys()
            ]
        ),
        refresh=False,
    )
    pbar.update()
# Out:
# episode_reward_mean_1 = 0, episode_reward_mean_3 = 0, episode_reward_mean_4 = 0, episode_reward_mean_5 = 0:   0%|          | 0/100 [00:00<?, ?it/s]2024-07-20 14:26:35,407 [torchrl][INFO]
# Iteration 0
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.891666889190674, episode_reward_mean_4 = -2.2874999046325684, episode_reward_mean_5 = -3.7291665077209473:   1%|          | 1/100 [03:44<6:10:44, 224.69s/it]2024-07-20 14:30:32,034 [torchrl][INFO]
# Iteration 1
# episode_reward_mean_1 = -1.8541666269302368, episode_reward_mean_3 = -3.9208335876464844, episode_reward_mean_4 = -2.2916667461395264, episode_reward_mean_5 = -3.945833444595337:   2%|▏         | 2/100 [14:40<13:00:50, 478.07s/it]2024-07-20 14:41:14,821 [torchrl][INFO]
# Iteration 2
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.3375000953674316, episode_reward_mean_5 = -3.5749998092651367:   3%|▎         | 3/100 [16:28<8:19:54, 309.23s/it]2024-07-20 14:43:03,201 [torchrl][INFO]
# Iteration 3
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.887500047683716, episode_reward_mean_4 = -2.2958333492279053, episode_reward_mean_5 = -4.191666603088379:   4%|▍         | 4/100 [18:13<6:06:03, 228.79s/it]   2024-07-20 14:44:49,254 [torchrl][INFO]
# Iteration 4
# episode_reward_mean_1 = -1.8333333730697632, episode_reward_mean_3 = -3.9208333492279053, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.9791667461395264:   5%|▌         | 5/100 [20:00<4:52:37, 184.82s/it]2024-07-20 14:46:35,390 [torchrl][INFO]
# Iteration 5
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9208333492279053, episode_reward_mean_4 = -2.2874999046325684, episode_reward_mean_5 = -3.7624998092651367:   6%|▌         | 6/100 [21:54<4:11:31, 160.55s/it]2024-07-20 14:48:28,212 [torchrl][INFO]
# Iteration 6
# episode_reward_mean_1 = -1.8541666269302368, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.2916667461395264, episode_reward_mean_5 = -4.008333206176758:   7%|▋         | 7/100 [23:48<3:45:32, 145.52s/it] 2024-07-20 14:50:22,722 [torchrl][INFO]
# Iteration 7
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.9125001430511475, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.9375:   8%|▊         | 8/100 [25:45<3:29:15, 136.47s/it]            2024-07-20 14:52:20,368 [torchrl][INFO]
# Iteration 8
# episode_reward_mean_1 = -1.8333332538604736, episode_reward_mean_3 = -3.883333206176758, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.795833110809326:   9%|▉         | 9/100 [27:47<3:19:53, 131.80s/it]2024-07-20 14:54:21,631 [torchrl][INFO]
# Iteration 9
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.9083333015441895, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.9625000953674316:  10%|█         | 10/100 [29:41<3:09:33, 126.37s/it]2024-07-20 14:56:17,188 [torchrl][INFO]
# Iteration 10
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.8958332538604736, episode_reward_mean_4 = -2.3125, episode_reward_mean_5 = -4.229166507720947:  11%|█         | 11/100 [31:41<3:04:32, 124.40s/it]            2024-07-20 14:58:16,406 [torchrl][INFO]
# Iteration 11
# episode_reward_mean_1 = -1.8541667461395264, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.2749998569488525, episode_reward_mean_5 = -4.183333396911621:  12%|█▏        | 12/100 [33:26<2:53:38, 118.40s/it]2024-07-20 15:00:00,834 [torchrl][INFO]
# Iteration 12
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.950000286102295, episode_reward_mean_4 = -2.320833206176758, episode_reward_mean_5 = -3.7333335876464844:  13%|█▎        | 13/100 [35:21<2:50:23, 117.52s/it]  2024-07-20 15:01:56,175 [torchrl][INFO]
# Iteration 13
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.9166667461395264, episode_reward_mean_4 = -2.3374998569488525, episode_reward_mean_5 = -3.5166666507720947:  14%|█▍        | 14/100 [37:12<2:45:27, 115.44s/it]2024-07-20 15:03:45,831 [torchrl][INFO]
# Iteration 14
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9375, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -4.195833206176758:  15%|█▌        | 15/100 [39:04<2:42:18, 114.57s/it]             2024-07-20 15:05:38,553 [torchrl][INFO]
# Iteration 15
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.887500047683716, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.7250001430511475:  16%|█▌        | 16/100 [40:45<2:34:41, 110.49s/it]2024-07-20 15:07:20,953 [torchrl][INFO]
# Iteration 16
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.933333396911621, episode_reward_mean_4 = -2.308333396911621, episode_reward_mean_5 = -3.762500047683716:  17%|█▋        | 17/100 [42:38<2:33:42, 111.11s/it] 2024-07-20 15:09:12,659 [torchrl][INFO]
# Iteration 17
# episode_reward_mean_1 = -1.8291666507720947, episode_reward_mean_3 = -3.9125001430511475, episode_reward_mean_4 = -2.3416666984558105, episode_reward_mean_5 = -3.4666666984558105:  18%|█▊        | 18/100 [44:36<2:34:45, 113.24s/it]2024-07-20 15:11:11,519 [torchrl][INFO]
# Iteration 18
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.9000000953674316, episode_reward_mean_4 = -2.3249998092651367, episode_reward_mean_5 = -3.5416665077209473:  19%|█▉        | 19/100 [46:27<2:32:02, 112.62s/it]2024-07-20 15:13:01,994 [torchrl][INFO]
# Iteration 19
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.8958334922790527, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.758333206176758:  20%|██        | 20/100 [48:24<2:31:41, 113.77s/it]  2024-07-20 15:14:58,922 [torchrl][INFO]
# Iteration 20
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.9083333015441895, episode_reward_mean_4 = -2.2750000953674316, episode_reward_mean_5 = -3.762500047683716:  21%|██        | 21/100 [50:18<2:29:54, 113.86s/it]2024-07-20 15:16:52,900 [torchrl][INFO]
# Iteration 21
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.9166665077209473, episode_reward_mean_4 = -2.3499999046325684, episode_reward_mean_5 = -3.5458333492279053:  22%|██▏       | 22/100 [52:07<2:26:13, 112.48s/it]2024-07-20 15:18:42,427 [torchrl][INFO]
# Iteration 22
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.941666603088379, episode_reward_mean_4 = -2.3375000953674316, episode_reward_mean_5 = -3.941666603088379:  23%|██▎       | 23/100 [54:03<2:25:45, 113.58s/it] 2024-07-20 15:20:38,499 [torchrl][INFO]
# Iteration 23
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.941666603088379, episode_reward_mean_4 = -2.320833206176758, episode_reward_mean_5 = -3.508333206176758:  24%|██▍       | 24/100 [55:48<2:20:33, 110.97s/it] 2024-07-20 15:22:23,354 [torchrl][INFO]
# Iteration 24
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.929166793823242, episode_reward_mean_4 = -2.2791666984558105, episode_reward_mean_5 = -3.795833110809326:  25%|██▌       | 25/100 [59:37<3:03:05, 146.48s/it]2024-07-20 15:26:26,900 [torchrl][INFO]
# Iteration 25
# episode_reward_mean_1 = -1.8291667699813843, episode_reward_mean_3 = -3.9541666507720947, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.9708333015441895:  26%|██▌       | 26/100 [1:05:48<4:23:34, 213.71s/it]2024-07-20 15:32:29,804 [torchrl][INFO]
# Iteration 26
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9041664600372314, episode_reward_mean_4 = -2.299999713897705, episode_reward_mean_5 = -3.9791665077209473:  27%|██▋       | 27/100 [1:10:54<4:53:39, 241.36s/it]2024-07-20 15:37:38,165 [torchrl][INFO]
# Iteration 27
# episode_reward_mean_1 = -1.8250000476837158, episode_reward_mean_3 = -3.9208333492279053, episode_reward_mean_4 = -2.3125, episode_reward_mean_5 = -3.9791665077209473:  28%|██▊       | 28/100 [1:14:42<4:44:59, 237.49s/it]           2024-07-20 15:41:25,998 [torchrl][INFO]
# Iteration 28
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.945833206176758, episode_reward_mean_4 = -2.304166555404663, episode_reward_mean_5 = -3.7916665077209473:  29%|██▉       | 29/100 [1:18:41<4:41:35, 237.96s/it]2024-07-20 15:45:26,678 [torchrl][INFO]
# Iteration 29
# episode_reward_mean_1 = -1.8541667461395264, episode_reward_mean_3 = -3.9375, episode_reward_mean_4 = -2.2874999046325684, episode_reward_mean_5 = -3.4791667461395264:  30%|███       | 30/100 [1:22:31<4:34:44, 235.49s/it]          2024-07-20 15:49:15,711 [torchrl][INFO]
# Iteration 30
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.941666603088379, episode_reward_mean_4 = -2.320833206176758, episode_reward_mean_5 = -3.4666666984558105:  31%|███       | 31/100 [1:26:25<4:30:17, 235.04s/it]2024-07-20 15:53:08,657 [torchrl][INFO]
# Iteration 31
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.8958332538604736, episode_reward_mean_4 = -2.2958333492279053, episode_reward_mean_5 = -4.183333396911621:  32%|███▏      | 32/100 [1:30:19<4:25:59, 234.70s/it]2024-07-20 15:57:04,636 [torchrl][INFO]
# Iteration 32
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.9250001907348633, episode_reward_mean_4 = -2.295833110809326, episode_reward_mean_5 = -3.6875:  33%|███▎      | 33/100 [1:34:21<4:24:37, 236.98s/it]             2024-07-20 16:01:05,021 [torchrl][INFO]
# Iteration 33
# episode_reward_mean_1 = -1.8541667461395264, episode_reward_mean_3 = -3.9166665077209473, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -4.220832824707031:  34%|███▍      | 34/100 [1:57:04<10:32:12, 574.74s/it]2024-07-20 16:23:40,737 [torchrl][INFO]
# Iteration 34
# episode_reward_mean_1 = -1.8333332538604736, episode_reward_mean_3 = -3.933333158493042, episode_reward_mean_4 = -2.3416666984558105, episode_reward_mean_5 = -3.758333206176758:  35%|███▌      | 35/100 [1:58:38<7:46:28, 430.59s/it] 2024-07-20 16:25:13,962 [torchrl][INFO]
# Iteration 35
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.950000047683716, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.679166555404663:  36%|███▌      | 36/100 [2:00:13<5:51:46, 329.79s/it] 2024-07-20 16:26:47,392 [torchrl][INFO]
# Iteration 36
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.933333396911621, episode_reward_mean_4 = -2.2916667461395264, episode_reward_mean_5 = -3.5166666507720947:  37%|███▋      | 37/100 [2:01:46<4:31:34, 258.64s/it]2024-07-20 16:28:19,655 [torchrl][INFO]
# Iteration 37
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.8874998092651367, episode_reward_mean_4 = -2.3125, episode_reward_mean_5 = -3.7666666507720947:  38%|███▊      | 38/100 [2:03:19<3:36:04, 209.11s/it]            2024-07-20 16:29:54,300 [torchrl][INFO]
# Iteration 38
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.9583334922790527, episode_reward_mean_4 = -2.2791666984558105, episode_reward_mean_5 = -4.2208333015441895:  39%|███▉      | 39/100 [2:04:53<2:57:21, 174.45s/it]2024-07-20 16:31:26,790 [torchrl][INFO]
# Iteration 39
# episode_reward_mean_1 = -1.8333333730697632, episode_reward_mean_3 = -3.945833206176758, episode_reward_mean_4 = -2.3249998092651367, episode_reward_mean_5 = -3.9666666984558105:  40%|████      | 40/100 [2:06:36<2:33:11, 153.19s/it]2024-07-20 16:33:10,454 [torchrl][INFO]
# Iteration 40
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.945833206176758, episode_reward_mean_4 = -2.3125, episode_reward_mean_5 = -3.9708333015441895:  41%|████      | 41/100 [2:08:22<2:16:42, 139.02s/it]             2024-07-20 16:34:57,766 [torchrl][INFO]
# Iteration 41
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.9083333015441895, episode_reward_mean_4 = -2.304166555404663, episode_reward_mean_5 = -3.9791665077209473:  42%|████▏     | 42/100 [2:10:06<2:04:13, 128.51s/it]2024-07-20 16:36:44,807 [torchrl][INFO]
# Iteration 42
# episode_reward_mean_1 = -1.8583333492279053, episode_reward_mean_3 = -3.950000047683716, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.566666603088379:  43%|████▎     | 43/100 [2:12:01<1:58:02, 124.25s/it] 2024-07-20 16:38:38,022 [torchrl][INFO]
# Iteration 43
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.304166555404663, episode_reward_mean_5 = -3.7916665077209473:  44%|████▍     | 44/100 [2:13:46<1:50:42, 118.62s/it]2024-07-20 16:40:23,355 [torchrl][INFO]
# Iteration 44
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.9166665077209473, episode_reward_mean_4 = -2.304166793823242, episode_reward_mean_5 = -3.9749999046325684:  45%|████▌     | 45/100 [2:15:34<1:45:45, 115.37s/it] 2024-07-20 16:42:11,660 [torchrl][INFO]
# Iteration 45
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.924999713897705, episode_reward_mean_4 = -2.2916665077209473, episode_reward_mean_5 = -3.4541666507720947:  46%|████▌     | 46/100 [2:17:19<1:41:02, 112.27s/it]2024-07-20 16:43:57,485 [torchrl][INFO]
# Iteration 46
# episode_reward_mean_1 = -1.8375000953674316, episode_reward_mean_3 = -3.9000000953674316, episode_reward_mean_4 = -2.304166555404663, episode_reward_mean_5 = -3.745833158493042:  47%|████▋     | 47/100 [2:19:05<1:37:33, 110.45s/it]2024-07-20 16:45:42,921 [torchrl][INFO]
# Iteration 47
# episode_reward_mean_1 = -1.8333333730697632, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.2958333492279053, episode_reward_mean_5 = -3.4708333015441895:  48%|████▊     | 48/100 [2:20:53<1:35:10, 109.82s/it]2024-07-20 16:47:31,859 [torchrl][INFO]
# Iteration 48
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.9041664600372314, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.508333206176758:  49%|████▉     | 49/100 [2:22:39<1:32:08, 108.40s/it]  2024-07-20 16:49:16,138 [torchrl][INFO]
# Iteration 49
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.9541666507720947, episode_reward_mean_4 = -2.3333334922790527, episode_reward_mean_5 = -3.9708333015441895:  50%|█████     | 50/100 [2:24:26<1:30:08, 108.18s/it]2024-07-20 16:51:03,384 [torchrl][INFO]
# Iteration 50
# episode_reward_mean_1 = -1.8333333730697632, episode_reward_mean_3 = -3.929166555404663, episode_reward_mean_4 = -2.3375000953674316, episode_reward_mean_5 = -3.6875:  51%|█████     | 51/100 [2:26:11<1:27:24, 107.02s/it]            2024-07-20 16:52:48,598 [torchrl][INFO]
# Iteration 51
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.875, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -4.1875:  52%|█████▏    | 52/100 [2:28:03<1:26:49, 108.52s/it]              2024-07-20 16:54:40,423 [torchrl][INFO]
# Iteration 52
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.8958334922790527, episode_reward_mean_4 = -2.3291666507720947, episode_reward_mean_5 = -3.758333206176758:  53%|█████▎    | 53/100 [2:29:49<1:24:38, 108.05s/it]2024-07-20 16:56:27,587 [torchrl][INFO]
# Iteration 53
# episode_reward_mean_1 = -1.8541666269302368, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.304166793823242, episode_reward_mean_5 = -3.5791666507720947:  54%|█████▍    | 54/100 [2:31:45<1:24:31, 110.25s/it]2024-07-20 16:58:24,238 [torchrl][INFO]
# Iteration 54
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.9083333015441895, episode_reward_mean_4 = -2.2833333015441895, episode_reward_mean_5 = -3.7249999046325684:  55%|█████▌    | 55/100 [2:33:41<1:24:01, 112.04s/it]2024-07-20 17:00:21,060 [torchrl][INFO]
# Iteration 55
# episode_reward_mean_1 = -1.8291666507720947, episode_reward_mean_3 = -3.9375, episode_reward_mean_4 = -2.2791666984558105, episode_reward_mean_5 = -3.504166603088379:  56%|█████▌    | 56/100 [2:35:38<1:23:14, 113.51s/it]            2024-07-20 17:02:17,591 [torchrl][INFO]
# Iteration 56
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.8958332538604736, episode_reward_mean_4 = -2.295833110809326, episode_reward_mean_5 = -3.7166666984558105:  57%|█████▋    | 57/100 [3:55:13<18:03:29, 1511.84s/it]2024-07-20 18:21:45,813 [torchrl][INFO]
# Iteration 57
# episode_reward_mean_1 = -1.8291666507720947, episode_reward_mean_3 = -3.9166667461395264, episode_reward_mean_4 = -2.3458333015441895, episode_reward_mean_5 = -3.762500047683716:  58%|█████▊    | 58/100 [3:56:33<12:37:43, 1082.47s/it]2024-07-20 18:23:05,954 [torchrl][INFO]
# Iteration 58
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9166665077209473, episode_reward_mean_4 = -2.2958333492279053, episode_reward_mean_5 = -3.7208333015441895:  59%|█████▉    | 59/100 [3:57:53<8:54:02, 781.53s/it] 2024-07-20 18:24:25,953 [torchrl][INFO]
# Iteration 59
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.8958332538604736, episode_reward_mean_4 = -2.304166555404663, episode_reward_mean_5 = -4.449999809265137:  60%|██████    | 60/100 [3:59:29<6:23:56, 575.91s/it]   2024-07-20 18:26:02,838 [torchrl][INFO]
# Iteration 60
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.933333396911621, episode_reward_mean_4 = -2.325000047683716, episode_reward_mean_5 = -3.758333206176758:  61%|██████    | 61/100 [4:01:08<4:41:23, 432.91s/it] 2024-07-20 18:27:42,058 [torchrl][INFO]
# Iteration 61
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.891666889190674, episode_reward_mean_4 = -2.2791666984558105, episode_reward_mean_5 = -3.983333110809326:  62%|██████▏   | 62/100 [4:02:43<3:29:53, 331.42s/it]2024-07-20 18:29:17,191 [torchrl][INFO]
# Iteration 62
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.887500047683716, episode_reward_mean_4 = -2.2874999046325684, episode_reward_mean_5 = -4.008333206176758:  63%|██████▎   | 63/100 [4:04:18<2:40:47, 260.73s/it]2024-07-20 18:30:52,778 [torchrl][INFO]
# Iteration 63
# episode_reward_mean_1 = -1.8250000476837158, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.2958333492279053, episode_reward_mean_5 = -4.008333206176758:  64%|██████▍   | 64/100 [4:05:59<2:07:35, 212.65s/it]2024-07-20 18:32:34,818 [torchrl][INFO]
# Iteration 64
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9250001907348633, episode_reward_mean_4 = -2.3125, episode_reward_mean_5 = -3.4750001430511475:  65%|██████▌   | 65/100 [4:07:58<1:47:41, 184.61s/it]           2024-07-20 18:34:33,440 [torchrl][INFO]
# Iteration 65
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.2833333015441895, episode_reward_mean_5 = -3.7249999046325684:  66%|██████▌   | 66/100 [4:10:02<1:34:22, 166.56s/it]2024-07-20 18:36:36,238 [torchrl][INFO]
# Iteration 66
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.933333396911621, episode_reward_mean_4 = -2.2833333015441895, episode_reward_mean_5 = -3.4749999046325684:  67%|██████▋   | 67/100 [4:11:38<1:19:49, 145.13s/it]  2024-07-20 18:38:12,020 [torchrl][INFO]
# Iteration 67
# episode_reward_mean_1 = -1.8250000476837158, episode_reward_mean_3 = -3.9375, episode_reward_mean_4 = -2.3125, episode_reward_mean_5 = -3.9749999046325684:  68%|██████▊   | 68/100 [4:13:18<1:10:19, 131.86s/it]                      2024-07-20 18:39:52,727 [torchrl][INFO]
# Iteration 68
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.2875001430511475, episode_reward_mean_5 = -3.7874999046325684:  69%|██████▉   | 69/100 [4:14:58<1:03:08, 122.22s/it]2024-07-20 18:41:32,609 [torchrl][INFO]
# Iteration 69
# episode_reward_mean_1 = -1.845833420753479, episode_reward_mean_3 = -3.887500047683716, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.695833444595337:  70%|███████   | 70/100 [4:16:36<57:27, 114.92s/it]      2024-07-20 18:43:10,681 [torchrl][INFO]
# Iteration 70
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.2666666507720947, episode_reward_mean_5 = -4.008333206176758:  71%|███████   | 71/100 [4:18:14<53:06, 109.89s/it]2024-07-20 18:44:48,881 [torchrl][INFO]
# Iteration 71
# episode_reward_mean_1 = -1.8541666269302368, episode_reward_mean_3 = -3.8958332538604736, episode_reward_mean_4 = -2.3000001907348633, episode_reward_mean_5 = -3.4750001430511475:  72%|███████▏  | 72/100 [4:19:54<49:52, 106.87s/it]2024-07-20 18:46:27,928 [torchrl][INFO]
# Iteration 72
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.929166793823242, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.9749999046325684:  73%|███████▎  | 73/100 [4:21:32<46:54, 104.22s/it]  2024-07-20 18:48:05,865 [torchrl][INFO]
# Iteration 73
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.875, episode_reward_mean_4 = -2.2833333015441895, episode_reward_mean_5 = -3.6875:  74%|███████▍  | 74/100 [4:23:11<44:31, 102.74s/it]                        2024-07-20 18:49:45,206 [torchrl][INFO]
# Iteration 74
# episode_reward_mean_1 = -1.8291666507720947, episode_reward_mean_3 = -3.887500047683716, episode_reward_mean_4 = -2.258333206176758, episode_reward_mean_5 = -3.983333110809326:  75%|███████▌  | 75/100 [4:24:57<43:06, 103.48s/it]2024-07-20 18:51:31,013 [torchrl][INFO]
# Iteration 75
# episode_reward_mean_1 = -1.8250000476837158, episode_reward_mean_3 = -3.875, episode_reward_mean_4 = -2.2791666984558105, episode_reward_mean_5 = -4.216666221618652:  76%|███████▌  | 76/100 [4:26:38<41:05, 102.75s/it]           2024-07-20 18:53:14,039 [torchrl][INFO]
# Iteration 76
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.8874998092651367, episode_reward_mean_4 = -2.2916667461395264, episode_reward_mean_5 = -4.004166603088379:  77%|███████▋  | 77/100 [4:28:18<39:07, 102.05s/it]2024-07-20 18:54:52,395 [torchrl][INFO]
# Iteration 77
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.875, episode_reward_mean_4 = -2.308333396911621, episode_reward_mean_5 = -3.512500047683716:  78%|███████▊  | 78/100 [4:29:57<37:05, 101.18s/it]               2024-07-20 18:56:31,890 [torchrl][INFO]
# Iteration 78
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.2916665077209473, episode_reward_mean_5 = -3.9749999046325684:  79%|███████▉  | 79/100 [4:31:39<35:28, 101.35s/it]2024-07-20 18:58:13,736 [torchrl][INFO]
# Iteration 79
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.8958334922790527, episode_reward_mean_4 = -2.2666666507720947, episode_reward_mean_5 = -3.6875:  80%|████████  | 80/100 [4:33:20<33:46, 101.35s/it]           2024-07-20 18:59:54,526 [torchrl][INFO]
# Iteration 80
# episode_reward_mean_1 = -1.8249999284744263, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.691666841506958:  81%|████████  | 81/100 [4:35:01<32:02, 101.17s/it]2024-07-20 19:01:35,348 [torchrl][INFO]
# Iteration 81
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.8958334922790527, episode_reward_mean_4 = -2.2833333015441895, episode_reward_mean_5 = -3.512500047683716:  82%|████████▏ | 82/100 [4:36:42<30:18, 101.04s/it]2024-07-20 19:03:15,477 [torchrl][INFO]
# Iteration 82
# episode_reward_mean_1 = -1.8208333253860474, episode_reward_mean_3 = -3.9041666984558105, episode_reward_mean_4 = -2.2916665077209473, episode_reward_mean_5 = -4.183333396911621:  83%|████████▎ | 83/100 [4:38:22<28:32, 100.76s/it]2024-07-20 19:04:55,600 [torchrl][INFO]
# Iteration 83
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.9083333015441895, episode_reward_mean_4 = -2.295833110809326, episode_reward_mean_5 = -3.575000047683716:  84%|████████▍ | 84/100 [4:40:07<27:13, 102.10s/it] 2024-07-20 19:06:41,660 [torchrl][INFO]
# Iteration 84
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.9083333015441895, episode_reward_mean_4 = -2.2708332538604736, episode_reward_mean_5 = -3.4749999046325684:  85%|████████▌ | 85/100 [4:41:48<25:24, 101.61s/it]2024-07-20 19:08:21,397 [torchrl][INFO]
# Iteration 85
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.8625001907348633, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.983333110809326:  86%|████████▌ | 86/100 [4:43:26<23:30, 100.73s/it]   2024-07-20 19:10:00,005 [torchrl][INFO]
# Iteration 86
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.929166555404663, episode_reward_mean_4 = -2.3499999046325684, episode_reward_mean_5 = -3.545833110809326:  87%|████████▋ | 87/100 [4:45:06<21:46, 100.47s/it]2024-07-20 19:11:40,246 [torchrl][INFO]
# Iteration 87
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.933333396911621, episode_reward_mean_4 = -2.3333334922790527, episode_reward_mean_5 = -4.004166603088379:  88%|████████▊ | 88/100 [4:46:45<19:59, 99.93s/it]2024-07-20 19:13:18,874 [torchrl][INFO]
# Iteration 88
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.9250001907348633, episode_reward_mean_4 = -2.3291664123535156, episode_reward_mean_5 = -3.795833110809326:  89%|████████▉ | 89/100 [4:48:24<18:18, 99.82s/it]2024-07-20 19:14:58,690 [torchrl][INFO]
# Iteration 89
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.9375, episode_reward_mean_4 = -2.2791666984558105, episode_reward_mean_5 = -4.2291669845581055:  90%|█████████ | 90/100 [4:50:05<16:39, 99.94s/it]           2024-07-20 19:16:38,313 [torchrl][INFO]
# Iteration 90
# episode_reward_mean_1 = -1.8666666746139526, episode_reward_mean_3 = -3.8958332538604736, episode_reward_mean_4 = -2.308333396911621, episode_reward_mean_5 = -4.454166889190674:  91%|█████████ | 91/100 [4:51:42<14:53, 99.23s/it]2024-07-20 19:18:16,236 [torchrl][INFO]
# Iteration 91
# episode_reward_mean_1 = -1.8333333730697632, episode_reward_mean_3 = -3.8999998569488525, episode_reward_mean_4 = -2.295833110809326, episode_reward_mean_5 = -3.741666555404663:  92%|█████████▏| 92/100 [4:53:22<13:16, 99.56s/it]2024-07-20 19:19:56,909 [torchrl][INFO]
# Iteration 92
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.8916666507720947, episode_reward_mean_4 = -2.2666666507720947, episode_reward_mean_5 = -3.7916665077209473:  93%|█████████▎| 93/100 [4:55:21<12:15, 105.12s/it]2024-07-20 19:21:55,829 [torchrl][INFO]
# Iteration 93
# episode_reward_mean_1 = -1.837499976158142, episode_reward_mean_3 = -3.933333396911621, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.9708333015441895:  94%|█████████▍| 94/100 [4:57:01<10:23, 103.84s/it]   2024-07-20 19:23:35,390 [torchrl][INFO]
# Iteration 94
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.9250001907348633, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.554166793823242:  95%|█████████▌| 95/100 [4:58:42<08:34, 102.81s/it]2024-07-20 19:25:15,849 [torchrl][INFO]
# Iteration 95
# episode_reward_mean_1 = -1.8416666984558105, episode_reward_mean_3 = -3.945833206176758, episode_reward_mean_4 = -2.3249998092651367, episode_reward_mean_5 = -3.7666666507720947:  96%|█████████▌| 96/100 [5:00:21<06:46, 101.69s/it]2024-07-20 19:26:55,007 [torchrl][INFO]
# Iteration 96
# episode_reward_mean_1 = -1.850000023841858, episode_reward_mean_3 = -3.929166793823242, episode_reward_mean_4 = -2.3333332538604736, episode_reward_mean_5 = -3.695833444595337:  97%|█████████▋| 97/100 [5:02:00<05:02, 100.93s/it]  2024-07-20 19:28:35,014 [torchrl][INFO]
# Iteration 97
# episode_reward_mean_1 = -1.8333333730697632, episode_reward_mean_3 = -3.9375, episode_reward_mean_4 = -2.262500047683716, episode_reward_mean_5 = -4.008333206176758:  98%|█████████▊| 98/100 [5:03:40<03:21, 100.68s/it]           2024-07-20 19:30:13,858 [torchrl][INFO]
# Iteration 98
# episode_reward_mean_1 = -1.8458333015441895, episode_reward_mean_3 = -3.9124999046325684, episode_reward_mean_4 = -2.299999952316284, episode_reward_mean_5 = -3.549999952316284:  99%|█████████▉| 99/100 [5:05:19<01:40, 100.25s/it]2024-07-20 19:31:53,822 [torchrl][INFO]
# Iteration 99
# episode_reward_mean_1 = -1.8249999284744263, episode_reward_mean_3 = -3.9583334922790527, episode_reward_mean_4 = -2.316666603088379, episode_reward_mean_5 = -3.7166666984558105: 100%|██████████| 100/100 [5:06:59<00:00, 99.91s/it]

# %% [markdown]
# ## Mean reward

# %%
plt.figure()
for group in env.group_map.keys():
    rewards = episode_reward_mean_map[group]
    plt.plot(rewards, label=group)

plt.title('Mean Rewards for All Groups')
plt.xlabel('Episode')
plt.ylabel('Mean Reward')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Losses

# %%
# Plot each tensor in separate figures
for key, tensor in training_tds.items():
    plt.figure(figsize=(8, 6))
    plt.plot(tensor.numpy())  # Convert tensor to numpy array and plot
    plt.title(key)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.grid(True)
    plt.show()

# %%
from services import plotter

plotter(params[kc.PLOTTER])

# %%
import os
from IPython.display import display, Markdown

# Path to the images directory
images_dir = '../../results/humans_mutation_sac_2'

# List all image files in the directory
images = [f for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

# Generate and display Markdown for each image
for image in images:
    markdown_image = f"![{image}]({images_dir}/{image})"
    display(Markdown(markdown_image))
# Out:
# ![actions.png](../../results/humans_mutation_sac_2/actions.png)
# ![actions_shifts.png](../../results/humans_mutation_sac_2/actions_shifts.png)
# ![rewards.png](../../results/humans_mutation_sac_2/rewards.png)
# ![simulation_length.png](../../results/humans_mutation_sac_2/simulation_length.png)
# ![travel_times.png](../../results/humans_mutation_sac_2/travel_times.png)
# ![tt_dist.png](../../results/humans_mutation_sac_2/tt_dist.png)
