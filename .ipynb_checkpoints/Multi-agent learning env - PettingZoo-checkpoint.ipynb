# %% [markdown]
# # Multi-Agent Reinforcement Learning PettingZoo

# %%
from environment import TrafficEnvironment
from keychain import Keychain as kc
import os
from services import Trainer
from services import create_agent_objects
from services import confirm_env_variable
from services import get_json
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_checker import check_env

import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.env.wrappers.pettingzoo_env import ParallelPettingZooEnv
from ray.tune.registry import register_env
from pettingzoo.test import parallel_api_test
from gymnasium.spaces import Box, Discrete
from ray.rllib.algorithms.dqn import DQNConfig
from ray.rllib.algorithms.dqn.dqn_torch_model import DQNTorchModel
from ray.rllib.env import PettingZooEnv
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.fcnet import FullyConnectedNetwork as TorchFC
from ray.rllib.utils.framework import try_import_torch
from ray.rllib.utils.torch_utils import FLOAT_MAX
from ray.tune.registry import register_env

from pettingzoo.classic import leduc_holdem_v4

from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from torch import nn
import gymnasium as gym

confirm_env_variable(kc.SUMO_HOME, append="tools")
params = get_json(kc.PARAMS_PATH)
# Out:
# [CONFIRMED] Environment variable exists: SUMO_HOME
# [SUCCESS] Added module directory: C:\Program Files (x86)\Eclipse\Sumo\tools
# [CONFIRMED] Environment variable exists: SUMO_HOME
# [SUCCESS] Added module directory: C:\Program Files (x86)\Eclipse\Sumo\tools

# %% [markdown]
# ###  Initialization of the TrafficEnvironment
#
# - **Network**: initialize network, create demand, create paths, calculate free flow travel times.
#
# - **Learning**: initialize observation and action space.

# %%
env = TrafficEnvironment(params[kc.SIMULATION_PARAMETERS])
# Out:
# [SUCCESS] Generated & saved 6 paths to: paths.csv
# [SUCCESS] Environment initiated!

# %% [markdown]
# ### Parallel API Test
#
# To make sure our custom environment is consistent with the API, we have the api_test, more information [here](https://pettingzoo.farama.org/content/environment_tests/).

# %%
parallel_api_test(env, num_cycles=1_000_000)
# Out:
# joint_action is:  {'agent1': 0, 'agent2': 1}
# agent1's action: 0
# agent2's action: 1
# reward is:  -92.0
#
#
#
# joint_action is:  {'agent1': 1, 'agent2': 1}
# agent1's action: 1
# agent2's action: 1
# reward is:  -92.5
#
#
#
# Passed Parallel API test

# %% [markdown]
# ### Ray

# %% [markdown]
# RLlib is an open-source library for reinforcement learning (RL), providing support for production-level, highly distributed RL workloads with unified APIs for multi-agent setups, offline dataset training, and externally connected simulators.

# %%
ray.init()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# The DQN algorithm will be implemented.

# %%
alg_name = "DQN"
ModelCatalog.register_custom_model("pa_model", TorchModelV2)

# %%
def env_creator():
        env = TrafficEnvironment(params[kc.SIMULATION_PARAMETERS])
        return env

# %% [markdown]
# Register the env

# %%
register_env("TrafficEnvironment", lambda config: PettingZooEnv(env_creator()))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
test_env = PettingZooEnv(env_creator())
obs_space = test_env.observation_space
act_space = gym.spaces.Discrete(3)
# Out:
# [SUCCESS] Generated & saved 6 paths to: paths.csv
# [SUCCESS] Environment initiated!

# %%
config = (
        DQNConfig()
        .environment(env="TrafficEnvironment")
        .rollouts(num_rollout_workers=1, rollout_fragment_length=30)
        .training(
            train_batch_size=200,
            hiddens=[],
            dueling=False,
            model={"custom_model": "pa_model"},
            optimizer={
            "Adam": {
                "lr": 0.01,  # learning rate
                "momentum": 0.9,  # momentum (if applicable)
                # Add other optimizer parameters as needed
            }
        }
        )
        .multi_agent(
            policies={
                "player_0": (None, obs_space, act_space, {}),
                "player_1": (None, obs_space, act_space, {}),
            },
            policy_mapping_fn=(lambda agent_id, *args, **kwargs: agent_id),
        )
        .resources(num_gpus=int(os.environ.get("RLLIB_NUM_GPUS", "0")))
        .debugging(
            log_level="DEBUG"
        )  # TODO: change to ERROR to match pistonball example
        .framework(framework="torch")
        .exploration(
            exploration_config={
                # The Exploration class to use.
                "type": "EpsilonGreedy",
                # Config for the Exploration class' constructor:
                "initial_epsilon": 0.1,
                "final_epsilon": 0.0,
                "epsilon_timesteps": 100000,  # Timesteps over which to anneal epsilon.
            }
        )
    )

# %%
config.environment(disable_env_checking=True)

# %%
tune.run(
        alg_name,
        name="DQN",
        stop={"timesteps_total": 10000000 if not os.environ.get("CI") else 50000},
        checkpoint_freq=10,
        config=config.to_dict(),
    )
# Out:
# 2024-01-29 18:37:48,482	INFO worker.py:1724 -- Started a local Ray instance.
# 2024-01-29 18:37:50,245	INFO tune.py:220 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2024-01-29 18:37:50,247	INFO tune.py:583 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\utils\passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\utils\passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# 2024-01-29 18:37:50,349	INFO tensorboardx.py:178 -- pip install "ray[tune]" to see TensorBoard files.
# 2024-01-29 18:37:50,350	WARNING callback.py:137 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-01-29 18:37:58</td></tr>
# <tr><td>Running for: </td><td>00:00:08.56        </td></tr>
# <tr><td>Memory:      </td><td>12.9/15.7 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/12 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name                        </th><th style="text-align: right;">  # failures</th><th>error file                                                                                           </th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_TrafficEnvironment_1fa3c_00000</td><td style="text-align: right;">           1</td><td>C:/Users/Anastasia/ray_results/DQN/DQN_TrafficEnvironment_1fa3c_00000_0_2024-01-29_18-37-50\error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                        </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_TrafficEnvironment_1fa3c_00000</td><td>ERROR   </td><td>     </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (DQN pid=26324) 2024-01-29 18:37:54,623	WARNING deprecation.py:50 -- DeprecationWarning: `rllib/algorithms/simple_q/` has been deprecated. Use `rllib_contrib/simple_q/` instead. This will raise an error in the future!
# 2024-01-29 18:37:58,896	ERROR tune_controller.py:1374 -- Trial task failed for trial DQN_TrafficEnvironment_1fa3c_00000
# Traceback (most recent call last):
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\worker.py", line 2626, in get
#     raise value
# ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::DQN.__init__() (pid=26324, ip=127.0.0.1, actor_id=e0fc07dea726c9b559668b0901000000, repr=DQN)
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\worker_set.py", line 229, in _setup
#     self.add_workers(
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\worker_set.py", line 616, in add_workers
#     raise result.get()
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 487, in __fetch_result
#     result = ray.get(r)
#              ^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\worker.py", line 2626, in get
#     raise value
# ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 741, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 527, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 393, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 370, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `TrafficEnvironment` doesn't exist. Did you mean: `GymV26Environment`?
#
# During handling of the above exception, another exception occurred:
#
# ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
#   File "python\ray\_raylet.pyx", line 1807, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1908, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1813, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1754, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 407, in __init__
#     self.env = env_creator(copy.deepcopy(self.env_context))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\env\utils.py", line 177, in _gym_env_creator
#     raise EnvError(ERR_MSG_INVALID_ENV_DESCRIPTOR.format(env_descriptor))
# ray.rllib.utils.error.EnvError: The env string you provided ('TrafficEnvironment') is:
# a) Not a supported/installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gym[atari] autorom[accept-rom-license]`.
#    For VizDoom support: Install VizDoom
#    (https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md) and
#    `pip install vizdoomgym`.
#    For PyBullet support: `pip install pybullet`.
# b) To register your custom env, do `from ray import tune;
#    tune.register('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config['env'] = [name]`.
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.env.repeat_after_me_env.RepeatAfterMeEnv`
#
# During handling of the above exception, another exception occurred:
#
# ray::DQN.__init__() (pid=26324, ip=127.0.0.1, actor_id=e0fc07dea726c9b559668b0901000000, repr=DQN)
#   File "python\ray\_raylet.pyx", line 1807, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1908, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1813, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1754, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\utils\deprecation.py", line 109, in patched_init
#     return obj_init(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 516, in __init__
#     super().__init__(
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\tune\trainable\trainable.py", line 161, in __init__
#     self.setup(copy.deepcopy(self.config))
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 638, in setup
#     self.workers = WorkerSet(
#                    ^^^^^^^^^^
#   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\worker_set.py", line 181, in __init__
#     raise e.args[0].args[2]
# ray.rllib.utils.error.EnvError: The env string you provided ('TrafficEnvironment') is:
# a) Not a supported/installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gym[atari] autorom[accept-rom-license]`.
#    For VizDoom support: Install VizDoom
#    (https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md) and
#    `pip install vizdoomgym`.
#    For PyBullet support: `pip install pybullet`.
# b) To register your custom env, do `from ray import tune;
#    tune.register('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config['env'] = [name]`.
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.env.repeat_after_me_env.RepeatAfterMeEnv`
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                        </th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_TrafficEnvironment_1fa3c_00000</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (DQN pid=26324) 2024-01-29 18:37:58,878	ERROR actor_manager.py:506 -- Ray error, taking actor 1 out of service. The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
# (DQN pid=26324)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 741, in make
# (DQN pid=26324)     env_spec = _find_spec(id)
# (DQN pid=26324)                ^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 527, in _find_spec
# (DQN pid=26324)     _check_version_exists(ns, name, version)
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 393, in _check_version_exists
# (DQN pid=26324)     _check_name_exists(ns, name)
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 370, in _check_name_exists
# (DQN pid=26324)     raise error.NameNotFound(
# (DQN pid=26324) gymnasium.error.NameNotFound: Environment `TrafficEnvironment` doesn't exist. Did you mean: `GymV26Environment`?
# (DQN pid=26324)
# (DQN pid=26324) During handling of the above exception, another exception occurred:
# (DQN pid=26324)
# (DQN pid=26324) ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1807, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1908, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1813, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1754, in ray._raylet.execute_task.function_executor
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
# (DQN pid=26324)     return method(__ray_actor, *args, **kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
# (DQN pid=26324)     return method(self, *_args, **_kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 407, in __init__
# (DQN pid=26324)     self.env = env_creator(copy.deepcopy(self.env_context))
# (DQN pid=26324)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\env\utils.py", line 177, in _gym_env_creator
# (DQN pid=26324)     raise EnvError(ERR_MSG_INVALID_ENV_DESCRIPTOR.format(env_descriptor))
# (DQN pid=26324) ray.rllib.utils.error.EnvError: The env string you provided ('TrafficEnvironment') is:
# (DQN pid=26324) a) Not a supported/installed environment.
# (DQN pid=26324) b) Not a tune-registered environment creator.
# (DQN pid=26324) c) Not a valid env class string.
# (DQN pid=26324)
# (DQN pid=26324) Try one of the following:
# (DQN pid=26324) a) For Atari support: `pip install gym[atari] autorom[accept-rom-license]`.
# (DQN pid=26324)    For VizDoom support: Install VizDoom
# (DQN pid=26324)    (https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md) and
# (DQN pid=26324)    `pip install vizdoomgym`.
# (DQN pid=26324)    For PyBullet support: `pip install pybullet`.
# (DQN pid=26324) b) To register your custom env, do `from ray import tune;
# (DQN pid=26324)    tune.register('[name]', lambda cfg: [return env obj from here using cfg])`.
# (DQN pid=26324)    Then in your config, do `config['env'] = [name]`.
# (DQN pid=26324) c) Make sure you provide a fully qualified classpath, e.g.:
# (DQN pid=26324)    `ray.rllib.examples.env.repeat_after_me_env.RepeatAfterMeEnv`
# (DQN pid=26324) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::DQN.__init__() (pid=26324, ip=127.0.0.1, actor_id=e0fc07dea726c9b559668b0901000000, repr=DQN)
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\worker_set.py", line 229, in _setup
# (DQN pid=26324)     self.add_workers(
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\worker_set.py", line 616, in add_workers
# (DQN pid=26324)     raise result.get()
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 487, in __fetch_result
# (DQN pid=26324)     result = ray.get(r)
# (DQN pid=26324)              ^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\auto_init_hook.py", line 22, in auto_init_wrapper
# (DQN pid=26324)     return fn(*args, **kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (DQN pid=26324)     return func(*args, **kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\worker.py", line 2626, in get
# (DQN pid=26324)     raise value
# (DQN pid=26324) ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
# (DQN pid=26324)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 741, in make
# (DQN pid=26324)     env_spec = _find_spec(id)
# (DQN pid=26324)                ^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 527, in _find_spec
# (DQN pid=26324)     _check_version_exists(ns, name, version)
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 393, in _check_version_exists
# (DQN pid=26324)     _check_name_exists(ns, name)
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\gymnasium\envs\registration.py", line 370, in _check_name_exists
# (DQN pid=26324)     raise error.NameNotFound(
# (DQN pid=26324) gymnasium.error.NameNotFound: Environment `TrafficEnvironment` doesn't exist. Did you mean: `GymV26Environment`?
# (DQN pid=26324)
# (DQN pid=26324) During handling of the above exception, another exception occurred:
# (DQN pid=26324)
# (DQN pid=26324) ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1807, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1908, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1813, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1754, in ray._raylet.execute_task.function_executor
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
# (DQN pid=26324)     return method(__ray_actor, *args, **kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
# (DQN pid=26324)     return method(self, *_args, **_kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 407, in __init__
# (DQN pid=26324)     self.env = env_creator(copy.deepcopy(self.env_context))
# (DQN pid=26324)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\env\utils.py", line 177, in _gym_env_creator
# (DQN pid=26324)     raise EnvError(ERR_MSG_INVALID_ENV_DESCRIPTOR.format(env_descriptor))
# (DQN pid=26324) ray.rllib.utils.error.EnvError: The env string you provided ('TrafficEnvironment') is:
# (DQN pid=26324) a) Not a supported/installed environment.
# (DQN pid=26324) b) Not a tune-registered environment creator.
# (DQN pid=26324) c) Not a valid env class string.
# (DQN pid=26324)
# (DQN pid=26324) Try one of the following:
# (DQN pid=26324) a) For Atari support: `pip install gym[atari] autorom[accept-rom-license]`.
# (DQN pid=26324)    For VizDoom support: Install VizDoom
# (DQN pid=26324)    (https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md) and
# (DQN pid=26324)    `pip install vizdoomgym`.
# (DQN pid=26324)    For PyBullet support: `pip install pybullet`.
# (DQN pid=26324) b) To register your custom env, do `from ray import tune;
# (DQN pid=26324)    tune.register('[name]', lambda cfg: [return env obj from here using cfg])`.
# (DQN pid=26324)    Then in your config, do `config['env'] = [name]`.
# (DQN pid=26324) c) Make sure you provide a fully qualified classpath, e.g.:
# (DQN pid=26324)    `ray.rllib.examples.env.repeat_after_me_env.RepeatAfterMeEnv`
# (DQN pid=26324)
# (DQN pid=26324) During handling of the above exception, another exception occurred:
# (DQN pid=26324)
# (DQN pid=26324) ray::DQN.__init__() (pid=26324, ip=127.0.0.1, actor_id=e0fc07dea726c9b559668b0901000000, repr=DQN)
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1807, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1908, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1813, in ray._raylet.execute_task
# (DQN pid=26324)   File "python\ray\_raylet.pyx", line 1754, in ray._raylet.execute_task.function_executor
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
# (DQN pid=26324)     return method(__ray_actor, *args, **kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
# (DQN pid=26324)     return method(self, *_args, **_kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\utils\deprecation.py", line 109, in patched_init
# (DQN pid=26324)     return obj_init(*args, **kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 516, in __init__
# (DQN pid=26324)     super().__init__(
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\tune\trainable\trainable.py", line 161, in __init__
# (DQN pid=26324)     self.setup(copy.deepcopy(self.config))
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
# (DQN pid=26324)     return method(self, *_args, **_kwargs)
# (DQN pid=26324)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\algorithms\algorithm.py", line 638, in setup
# (DQN pid=26324)     self.workers = WorkerSet(
# (DQN pid=26324)                    ^^^^^^^^^^
# (DQN pid=26324)   File "C:\Users\Anastasia\anaconda3\Lib\site-packages\ray\rllib\evaluation\worker_set.py", line 181, in __init__
# (DQN pid=26324)     raise e.args[0].args[2]
# (DQN pid=26324) ray.rllib.utils.error.EnvError: The env string you provided ('TrafficEnvironment') is:
# (DQN pid=26324) a) Not a supported/installed environment.
# (DQN pid=26324) b) Not a tune-registered environment creator.
# (DQN pid=26324) c) Not a valid env class string.
# (DQN pid=26324)
# (DQN pid=26324) Try one of the following:
# (DQN pid=26324) a) For Atari support: `pip install gym[atari] autorom[accept-rom-license]`.
# (DQN pid=26324)    For VizDoom support: Install VizDoom
# (DQN pid=26324)    (https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md) and
# (DQN pid=26324)    `pip install vizdoomgym`.
# (DQN pid=26324)    For PyBullet support: `pip install pybullet`.
# (DQN pid=26324) b) To register your custom env, do `from ray import tune;
# (DQN pid=26324)    tune.register('[name]', lambda cfg: [return env obj from here using cfg])`.
# (DQN pid=26324)    Then in your config, do `config['env'] = [name]`.
# (DQN pid=26324) c) Make sure you provide a fully qualified classpath, e.g.:
# (DQN pid=26324)    `ray.rllib.examples.env.repeat_after_me_env.RepeatAfterMeEnv`
# (RolloutWorker pid=8664) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=8664, ip=127.0.0.1, actor_id=8b91b63b8e27751cbfb807f301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000020683CDA950>)
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tune.run(
#       2         alg_name,
#       3         name="DQN",
#       4         stop={"timesteps_total": 10000000 if not os.environ.get("CI") else 50000},
#       5         checkpoint_freq=10,
#       6         config=config.to_dict(),
#       7     )
#
# File ~\anaconda3\Lib\site-packages\ray\tune\tune.py:1036, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1034 if incomplete_trials:
#    1035     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1036         raise TuneError("Trials did not complete", incomplete_trials)
#    1037     else:
#    1038         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [DQN_TrafficEnvironment_1fa3c_00000])
